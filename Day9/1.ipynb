# %%
class Demo:
    def __init__(self, a, b):
        self.a = a
        self.b = b

    def sums(self):
        return self.a + self.b


obj = Demo(10, 20)
print(obj.sums())
# Out:
# 30

# %%
class Demo:
    def __init__(self):
        pass
    def add(self, a,b):
        print("Sum is ", a+b)

# %%
class Demo:
    def __init__(jon):
        pass
    def add(self, a,b):
        print("The Addition is ", a+b)

# %%
class Demo:
    def __init__(self, a, b, c):
        self.a = a
        self.b = b
        self.c = c
    def largest(self):
        if self.a >= self.b and self.a >= self.c:
            return self.a
        elif self.b >= self.a and self.b >= self.c:
            return self.b
        else:
            return self.c
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
obj = Demo(a, b, c)
print("The largest no. is", obj.largest())
# Out:
# The largest no. is 10
