# %%
import pandas as pd

# %%
data={
    "name":['Bhavya','Aman','Pawan'],
    "emp_id":[100,200,300],
    "unit":[10,20,30],
    "City":['gurugram','raipur','banaras'],
    "Cp":[100,200,300],
    "Sp":[200,100,400],
    "Diff": [100,-100,100],
    "Total_cost": [100,200,300]


}

df=pd.DataFrame(data)
df
# Out:
#      name  emp_id  unit      City   Cp   Sp  Diff  Total_cost
# 0  Bhavya     100    10  gurugram  100  200   100         100
# 1    Aman     200    20    raipur  200  100  -100         200
# 2   Pawan     300    30   banaras  300  400   100         300

# %%
df["Prof_loss"]=df["Diff"].apply(lambda x: "Profit" if x>0 else "Loss")
df
# Out:
#      name  emp_id  unit      City   Cp   Sp  Diff  Total_cost Prof_loss
# 0  Bhavya     100    10  gurugram  100  200   100         100    Profit
# 1    Aman     200    20    raipur  200  100  -100         200      Loss
# 2   Pawan     300    30   banaras  300  400   100         300    Profit

# %%
df["order_type"] = df["unit"].apply(
    lambda x: "Bulk Order" if x > 20 else "Normal Order"
)
df
# Out:
#      name  emp_id  unit      City   Cp   Sp  Diff  Total_cost Prof_loss  \
# 0  Bhavya     100    10  gurugram  100  200   100         100    Profit
# 1    Aman     200    20    raipur  200  100  -100         200      Loss
# 2   Pawan     300    30   banaras  300  400   100         300    Profit
#
#      order_type
# 0  Normal Order
# 1  Normal Order
# 2    Bulk Order
